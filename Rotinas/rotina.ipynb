# %% [markdown]
# # 🧬 ROTINA DE VIDA - Deivison Santana
#
# > **Criado:** 02 Novembro 2025
# > **Atualizado:** 02 Novembro 2025
# > **Fonte:** Conversas Grok Doctor Mode + Claude DevSan
#
# ---
#
# ## 🎯 OBJETIVO
#
# Rotina estruturada baseada em:
#
# 1. **Alimentação** - Ganhar 10kg (60→70kg)
# 2. **Saúde Física** - Massa muscular, energia
# 3. **Saúde Mental** - Reduzir ansiedade oral
# 4. **Produtividade** - Trabalho UFRB CETENS + side hustles
#
# ---

# %% [markdown]
# ## 📊 DADOS CONTEXTUAIS

# %%
# Perfil Deivison
perfil = {
    "nome": "Deivison Santana",
    "idade": 25,
    "peso_atual_kg": 60,
    "peso_meta_kg": 70,
    "altura_m": 1.75,  # estimado
    "trabalho": "Técnico TI UFRB CETENS",
    "horario_trabalho": "Segunda-Sexta 8h-18h",
    "local": "Feira de Santana/BA"
}

# Finanças
financas = {
    "renda_liquida_mensal": 1866.53,
    "vale_alimentacao": 420,  # Pluxee/Sodexo
    "vale_transporte": 320,
    "gastos_fixos": {
        "agua": 150,
        "luz": 150,
        "internet": 80
    },
    "orcamento_compras_quinzenal": (200, 250)  # min, max
}

# Calcular sobra mensal
gastos_fixos_total = sum(financas["gastos_fixos"].values())
sobra_mensal = financas["renda_liquida_mensal"] - gastos_fixos_total

print(f"💰 Sobra mensal: R$ {sobra_mensal:.2f}")
print(f"🛒 Orçamento quinzenal compras: R$ {financas['orcamento_compras_quinzenal'][0]}-{financas['orcamento_compras_quinzenal'][1]}")
# Out:
# A execução de células com 'Python 3.13.7' requer o pacote ipykernel.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Crie um ambiente Python</a> com os pacotes necessários.
#
# Ou instale 'ipykernel' usando o comando: '/bin/python -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## 🍽️ ROTINA ALIMENTAÇÃO

# %% [markdown]
# ### ☕ CAFÉ MANHÃ (7h30 - Copa Trabalho)
#
# **Segunda a Sexta:**
# - 2 pães forma + 2 hambúrgueres + manteiga (sanduicheira)
# - Café grátis (copa)
# - OU limonada (limão tahiti)
#
# **Sábado/Domingo (Casa):**
# - 2 pães forma + 2 hambúrgueres + manteiga
# - OU cuscuz + ovo + mortadela
# - Café/suco
#
# ---

# %%
# Cálculo hambúrgueres semana
hamburgueres_por_dia = {
    "seg_sex": 3,  # 2 manhã + 1 tarde
    "sab_dom": 2   # 2 manhã
}

total_semanal = (hamburgueres_por_dia["seg_sex"] * 5) + (hamburgueres_por_dia["sab_dom"] * 2)
total_quinzenal = total_semanal * 2

print(f"🍔 Hambúrgueres por semana: {total_semanal}")
print(f"🍔 Hambúrgueres quinzenal: {total_quinzenal}")
print(f"\n📦 Comprar: {total_semanal} hambúrgueres congelados")

# %% [markdown]
# ### 🍽️ ALMOÇO (12h - Vale R$ 420)
#
# **Segunda a Sexta:**
# - Coberto vale alimentação (trabalho)
# - Variação diária (arroz, feijão, frango, salada)
#
# **Sábado/Domingo (Casa):**
# - Arroz + feijão + frango (asinha/coxa/peito) + cenoura
# - OU macarrão + molho tomate + ovo
# - 2 bananas picadas (sobremesa)
#
# ---

# %% [markdown]
# ### 🍌 LANCHE TARDE (16h - Trabalho)
#
# **Segunda a Sexta:**
# - 1 pão forma + 1 hambúrguer + manteiga (sanduicheira)
# - 2 bananas (come 2, não 1!)
# - OU 1 maçã + biscoito
# - Café grátis copa OU limonada
#
# **Sábado/Domingo:**
# - Fruta + biscoito
# - OU cuscuz light
#
# ---

# %%
# Cálculo bananas
bananas_por_dia = 2  # linha 544: "Geralmente eu não como uma só, eu como duas"
dias_quinzenal = 10  # ~10 dias úteis quinzenal

bananas_kg = (bananas_por_dia * dias_quinzenal * 0.15)  # 150g por banana

print(f"🍌 Bananas por dia: {bananas_por_dia}")
print(f"🍌 Total quinzenal: ~{bananas_kg:.1f}kg")
print(f"\n📦 Comprar: 3kg banana prata (verde, dura 10 dias)")

# %% [markdown]
# ### 🌙 JANTA (19h30 - Casa)
#
# **Opções Modulares:**
#
# 1. **Arroz + Feijão + Frango** (asinha/coxa/peito) + cenoura refogada
# 2. **Macarrão** + molho tomate + ovo cozido
# 3. **Cuscuz** + mortadela + cenoura ralada
# 4. **Batata doce** cozida + frango grelhado + tomate
# 5. **Banana terra** cozida + ovo frito + feijão
#
# ---

# %% [markdown]
# ## 📅 ROTINA SEMANAL

# %%
import pandas as pd

# Rotina Segunda a Sexta
rotina_trabalho = pd.DataFrame([
    {"Horário": "5h45", "Ação": "⏰ Acordar, banho, vestir"},
    {"Horário": "6h05", "Ação": "🚌 Pegar ônibus (levar 3 pães + 3 hambúrgueres + 2 bananas)"},
    {"Horário": "7h20", "Ação": "🏢 Chegar trabalho"},
    {"Horário": "7h25", "Ação": "☕ Copa: sanduicheira 2 pães + 2 hambúrgueres + café"},
    {"Horário": "8h", "Ação": "💻 Início expediente"},
    {"Horário": "12h", "Ação": "🍽️ Almoço (vale R$ 420)"},
    {"Horário": "13h", "Ação": "💻 Retorno trabalho"},
    {"Horário": "16h", "Ação": "🍌 Lanche: 1 pão + 1 hambúrguer + 2 bananas + café"},
    {"Horário": "18h", "Ação": "🚶 Sair trabalho"},
    {"Horário": "18h10", "Ação": "🚌 Pegar ônibus"},
    {"Horário": "19h30", "Ação": "🏠 Chegar casa"},
    {"Horário": "19h45", "Ação": "🌙 Janta (opções modulares)"},
    {"Horário": "20h15", "Ação": "🧼 Lavar louça, arrumar bolsa"},
    {"Horário": "22h", "Ação": "😴 Dormir"}
])

display(rotina_trabalho)

# %%
# Rotina Final de Semana (Sábado/Domingo)
rotina_fds = pd.DataFrame([
    {"Horário": "8h-9h", "Dia": "Domingo", "Ação": "🛒 Compras quinzenal (Da Praça Tomba OU Assaí)"},
    {"Horário": "10h", "Dia": "Sáb/Dom", "Ação": "☕ Café manhã casa (2 pães + 2 hambúrgueres)"},
    {"Horário": "12h-13h", "Dia": "Domingo", "Ação": "🍳 Batch cooking (grelhar frangos, cozinhar ovos, separar porções)"},
    {"Horário": "14h", "Dia": "Sáb/Dom", "Ação": "🍽️ Almoço (arroz + feijão + frango + 2 bananas)"},
    {"Horário": "16h", "Dia": "Sáb/Dom", "Ação": "🍌 Lanche (fruta + biscoito)"},
    {"Horário": "19h30", "Dia": "Sáb/Dom", "Ação": "🌙 Janta (macarrão OU cuscuz OU batata doce)"},
    {"Horário": "22h", "Dia": "Sáb/Dom", "Ação": "😴 Dormir"}
])

display(rotina_fds)

# %% [markdown]
# ## 🍳 BATCH COOKING DOMINGO

# %%
# Checklist Batch Cooking
batch_cooking = pd.DataFrame([
    {"Item": "Asinha frango 1kg", "Ação": "Grelhar + separar 10 porções", "Armazenamento": "Freezer (5 dias)"},
    {"Item": "Coxa frango 1kg", "Ação": "Grelhar + separar 10 porções", "Armazenamento": "Freezer (5 dias)"},
    {"Item": "Ovos 10un", "Ação": "Cozinhar inteiros", "Armazenamento": "Geladeira (7 dias)"},
    {"Item": "Bananas 3kg", "Ação": "Lavar, embalar verdes", "Armazenamento": "Geladeira (10 dias)"},
    {"Item": "Maçãs 1kg", "Ação": "Lavar, embalar firmes", "Armazenamento": "Geladeira (10 dias)"},
    {"Item": "Batata doce 2kg", "Ação": "Cozinhar + separar porções", "Armazenamento": "Freezer (10 dias)"},
    {"Item": "Cenoura 1kg", "Ação": "Lavar, descascar, ralar metade", "Armazenamento": "Geladeira (5 dias)"}
])

display(batch_cooking)

# %% [markdown]
# ## 🧠 ANSIEDADE ORAL - ESTRATÉGIAS

# %% [markdown]
# ### Quando bater impulso oral:
#
# 1. **Goma sem açúcar** - Mascar (sensação oral)
# 2. **Banana** - Doce natural, saciedade
# 3. **Biscoito cream cracker** - Crocante, baixo calórico
# 4. **Cenoura crua palitos** - Crunch, fibras
# 5. **Limonada gelada** - Ácido, refrescante, distração
# 6. **Café** - Grátis trabalho, quebra ansiedade
#
# ---

# %% [markdown]
# ## 📝 PRÓXIMOS PASSOS

# %%
# Checklist Próximos Passos
proximos_passos = pd.DataFrame([
    {"Fase": "2", "Tarefa": "Criar rotinas específicas seg-dom", "Status": "⏳ Pendente"},
    {"Fase": "2", "Tarefa": "Adicionar opções modulares janta", "Status": "⏳ Pendente"},
    {"Fase": "3", "Tarefa": "Conversa Grok sobre limpeza", "Status": "⏳ Pendente"},
    {"Fase": "3", "Tarefa": "Adicionar produtos limpeza lista", "Status": "⏳ Pendente"},
    {"Fase": "4", "Tarefa": "Mapear FGTS acumulado", "Status": "⏳ Pendente"},
    {"Fase": "4", "Tarefa": "Patrimônio líquido completo", "Status": "⏳ Pendente"},
    {"Fase": "5", "Tarefa": "Tracking sono/energia/peso", "Status": "⏳ Pendente"}
])

display(proximos_passos)

# %% [markdown]
# ---
#
# **🔥 LEMBRETE:** Este notebook evolui diariamente. Sempre ler transcrições atualizadas!
#
# **Fontes:**
# - `../Transcricoes/conversa-alimentacao-raw.txt`
# - `../Transcricoes/conversa-atualizacao-refatoracao.txt`
# - `LISTA-COMPRAS-03NOV-QUINZENAL.md`
#
# ---
#
# **Criado por:** Deivison + DevSan (Claude) + Grok Doctor Mode
